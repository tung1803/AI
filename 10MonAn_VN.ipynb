# %% [markdown]
# <a href="https://colab.research.google.com/github/tung1803/AI/blob/main/10MonAn_VN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/data/Mon_an_VN/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+'BanhBotLoc.'+str(i+1)+'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder = '/content/drive/MyDrive/data/Mon_an_VN/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('BanhBotLoc'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhChung'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhDay'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhMi'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhXeo'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BunDauMamTom'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('CheBuoi'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('ComTam'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Pho'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('XoiGa'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)
# Out:
# (90, 200, 200, 3) (90,)

# %%
# Model CNN
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi

model = Sequential([
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(200, 200, 3)),
    MaxPooling2D((2, 2)),
    
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(photos, labels, epochs=15, verbose=1)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 5s 1s/step - loss: 1763.1670 - accuracy: 0.1111
# Epoch 2/15
# 3/3 [==============================] - 5s 1s/step - loss: 1152.2068 - accuracy: 0.1000
# Epoch 3/15
# 3/3 [==============================] - 5s 2s/step - loss: 166.2387 - accuracy: 0.1667
# Epoch 4/15
# 3/3 [==============================] - 5s 1s/step - loss: 5.3357 - accuracy: 0.5889
# Epoch 5/15
# 3/3 [==============================] - 4s 1s/step - loss: 0.7546 - accuracy: 0.8556
# Epoch 6/15
# 3/3 [==============================] - 4s 1s/step - loss: 0.2835 - accuracy: 0.9111
# Epoch 7/15
# 3/3 [==============================] - 4s 1s/step - loss: 0.0962 - accuracy: 0.9778
# Epoch 8/15
# 3/3 [==============================] - 4s 1s/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 9/15
# 3/3 [==============================] - 5s 2s/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 10/15
# 3/3 [==============================] - 4s 1s/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 11/15
# 3/3 [==============================] - 5s 1s/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 12/15
# 3/3 [==============================] - 4s 1s/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 13/15
# 3/3 [==============================] - 5s 1s/step - loss: 6.5792e-04 - accuracy: 1.0000
# Epoch 14/15
# 3/3 [==============================] - 4s 1s/step - loss: 2.6289e-04 - accuracy: 1.0000
# Epoch 15/15
# 3/3 [==============================] - 5s 1s/step - loss: 1.7741e-04 - accuracy: 1.0000

# %%
model.evaluate(photos,labels)
# Out:
# 3/3 [==============================] - 1s 403ms/step - loss: 1.1589e-04 - accuracy: 1.0000
# [0.00011589397036004812, 1.0]

# %%
model.save('10Foods_Final.h5')

# %%
from keras.models import load_model
models=load_model('10Foods_Final.h5')

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('BunDauMamTom.3.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
# Out:
# [[0.08850676 0.10104508 0.09584086 0.0947897  0.10132672 0.11620498
#   0.09958095 0.10781407 0.10206561 0.09282529]]
# [5]
