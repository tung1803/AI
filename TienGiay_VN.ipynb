# %% [markdown]
# <a href="https://colab.research.google.com/github/tung1803/AI/blob/main/TienGiay_VN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/data/Tien_Giay_VN/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+'100dong.'+str(i+1)+'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder= '/content/drive/MyDrive/data/Tien_Giay_VN/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('200dong'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('500dong'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('1000dong'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('2000dong'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('5000dong'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('10000dong'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('20000dong'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('50000dong'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('100000dong'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('200000dong'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('500000dong'):
    output = 10
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('11TienGiay_photos.npy', photos)
save('11TienGiay_labels.npy', labels)
# Out:
# (110, 200, 200, 3) (110,)

# %%
#Model CNN
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi
from tensorflow.keras.optimizers import SGD

model = Sequential([
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(200, 200, 3)),
    MaxPooling2D((2, 2)),
    
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    Flatten(),
    Dense(64, activation='relu'),
    Dense(11, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(photos, labels, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 6s 1s/step - loss: 0.0423 - accuracy: 0.9909
# Epoch 2/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.2365 - accuracy: 0.9636
# Epoch 3/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.3598 - accuracy: 0.9636
# Epoch 4/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0990 - accuracy: 1.0000
# Epoch 5/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.4064 - accuracy: 0.9545
# Epoch 6/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.1612 - accuracy: 1.0000
# Epoch 7/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.2152 - accuracy: 0.9818
# Epoch 8/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.2499 - accuracy: 0.9182
# Epoch 9/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.2348 - accuracy: 0.9818
# Epoch 10/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0390 - accuracy: 0.9909
# Epoch 11/20
# 4/4 [==============================] - 5s 1s/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 12/20
# 4/4 [==============================] - 5s 1s/step - loss: 8.4360e-04 - accuracy: 1.0000
# Epoch 13/20
# 4/4 [==============================] - 5s 1s/step - loss: 1.1555e-04 - accuracy: 1.0000
# Epoch 14/20
# 4/4 [==============================] - 5s 1s/step - loss: 6.0839e-05 - accuracy: 1.0000
# Epoch 15/20
# 4/4 [==============================] - 5s 1s/step - loss: 2.8534e-05 - accuracy: 1.0000
# Epoch 16/20
# 4/4 [==============================] - 5s 1s/step - loss: 1.4384e-05 - accuracy: 1.0000
# Epoch 17/20
# 4/4 [==============================] - 5s 1s/step - loss: 7.3039e-06 - accuracy: 1.0000
# Epoch 18/20
# 4/4 [==============================] - 5s 1s/step - loss: 5.1729e-06 - accuracy: 1.0000
# Epoch 19/20
# 4/4 [==============================] - 5s 1s/step - loss: 3.8414e-06 - accuracy: 1.0000
# Epoch 20/20
# 4/4 [==============================] - 5s 1s/step - loss: 2.8489e-06 - accuracy: 1.0000

# %%
model.evaluate(photos,labels)
# Out:
# 4/4 [==============================] - 2s 343ms/step - loss: 2.5552e-06 - accuracy: 1.0000
# [2.5552496936143143e-06, 1.0]

# %%
model.save('TienGiay_Final.h5')

# %%
from keras.models import load_model
models=load_model('TienGiay_Final.h5')

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('2000dong.2.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
# Out:
# [[0.10217907 0.09425014 0.08964363 0.13986383 0.08981561 0.07109273
#   0.10831133 0.06969473 0.08570775 0.06324901 0.08619217]]
# [3]
